# %%
import os
import paramiko
from scp import SCPClient
from datetime import datetime
import time
import ctypes
from ctypes import wintypes
import sys
from typing import Dict, Any, Optional

# --- WINDOWS SLEEP PREVENTION ---

# Constants from winnt.h
ES_CONTINUOUS = 0x80000000
ES_SYSTEM_REQUIRED = 0x00000001
ES_DISPLAY_REQUIRED = 0x00000002

def prevent_sleep():
    """Enable system sleep prevention."""
    # Only run on Windows
    if sys.platform.startswith('win'):
        ctypes.windll.kernel32.SetThreadExecutionState(
            ES_CONTINUOUS | ES_SYSTEM_REQUIRED | ES_DISPLAY_REQUIRED
        )

def allow_sleep():
    """Allow sleep again."""
    # Only run on Windows
    if sys.platform.startswith('win'):
        ctypes.windll.kernel32.SetThreadExecutionState(ES_CONTINUOUS)

# --- HELPER FUNCTION ---

def file_exists_in_subdirs(root_dir: str, filename: str) -> bool:
    """Recursively search for filename in root_dir and subdirectories."""
    # This assumes the file on the controller is the exact name we are saving locally
    for dirpath, _, filenames in os.walk(root_dir):
        if filename in filenames:
            return True
    return False

# --- MAIN DOWNLOAD FUNCTION ---

def download_remote_files(
    device_config: Dict[str, Any],
    mode: str = 'once',  # 'once' or 'continuous'
    t_hour: float = 0.25 # Time between runs for 'continuous' mode (in hours)
) -> None:
    """
    Connects to a remote device via SSH/SCP and downloads files.

    Args:
        device_config: Dictionary containing 'host', 'port', 'user', 'password', 
                       'remote_folder', and 'local_root_folder'.
        mode: 'once' for a single download, 'continuous' to loop.
        t_hour: Sleep duration in hours for 'continuous' mode.
    """
    
    # Unpack configuration
    REMOTE_HOST = device_config['host']
    REMOTE_PORT = device_config['port']
    USERNAME = device_config['user']
    PASSWORD = device_config['password']
    REMOTE_FOLDER = device_config['remote_folder']
    #LOCAL_ROOT_FOLDER = device_config['local_root_folder']
    
    # Calculate sleep duration in seconds
    SLEEP_DURATION = t_hour * 60 * 60 

    def _do_download():
        """The core logic for connecting and downloading."""
        print(f"[{datetime.now()}] Starting SCP download job from {REMOTE_HOST}...")

        if not os.path.exists(LOCAL_ROOT_FOLDER):
            print(f"Creating local folder: {LOCAL_ROOT_FOLDER}")
            os.makedirs(LOCAL_ROOT_FOLDER)

        ssh = paramiko.SSHClient()
        ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
        
        try:
            # 1. Connect
            print(f"[{datetime.now()}] Attempting to connect to {USERNAME}@{REMOTE_HOST}:{REMOTE_PORT}")
            ssh.connect(REMOTE_HOST, port=REMOTE_PORT, username=USERNAME, password=PASSWORD)

            # 2. List Files - FIX APPLIED HERE
            # The 'ls -p | grep -v /' command lists files but excludes directories (which end in /).
            # This is key for devices that may have directories in the data folder.
            list_command = f'ls -p {REMOTE_FOLDER} | grep -v /'
            stdin, stdout, stderr = ssh.exec_command(list_command)
            
            # --- FIX: Read stdout once ---
            output = stdout.read().decode().strip()
            
            files = output.splitlines()

            if not files:
                print(f"[{datetime.now()}] No files found in remote directory: {REMOTE_FOLDER}")
                return

            # 3. Download Files
            with SCPClient(ssh.get_transport()) as scp:
                for file in files:
                    remote_path = f"{REMOTE_FOLDER}/{file}"
                    # Note: We use os.path.join for the local path for platform independence
                    local_target_path = os.path.join(LOCAL_ROOT_FOLDER, file)
                    
                    if file_exists_in_subdirs(LOCAL_ROOT_FOLDER, file):
                        print(f"Skipping (already exists locally): {file}")
                    else:
                        print(f"Downloading: {file}")
                        # scp.get handles file existence checks on the remote side gracefully
                        scp.get(remote_path, local_target_path)
            
            print(f"[{datetime.now()}] Download job completed successfully.")

        except paramiko.AuthenticationException:
            print(f"[{datetime.now()}] Error: Authentication failed for {USERNAME}@{REMOTE_HOST}")
        except paramiko.SSHException as e:
            print(f"[{datetime.now()}] Error: SSH connection or command failed: {e}")
        except Exception as e:
            print(f"[{datetime.now()}] General Error during download: {e}")
        finally:
            ssh.close()
            
    # --- Mode Execution Logic ---
    
    if mode == 'once':
        _do_download()
        
    elif mode == 'continuous':
        print(f"Starting continuous SCP downloader for {REMOTE_HOST}...")
        print("Press Ctrl+C to stop.")
        
        # Prevent system sleep while script is running
        prevent_sleep()
        
        try:
            _do_download() # Initial run
            
            while True:
                print(f"[{datetime.now()}] Waiting {t_hour} hours ({int(SLEEP_DURATION)} seconds) before next run...")
                time.sleep(SLEEP_DURATION)
                print(f"[{datetime.now()}] Waking up for next download cycle.")
                _do_download()
                
        except KeyboardInterrupt:
            print("\nScript stopped by user.")
        finally:
            allow_sleep()
            
    else:
        print(f"Error: Invalid mode '{mode}'. Use 'once' or 'continuous'.")


# --- CONFIGURATION DICTIONARIES ---

LOCAL_ROOT_FOLDER = r"C:/Users/rhansen/Documents/Python/SPMs/Intersections/SH-55 & Banks-Lowman/Data/DATZ/"

# Traffic Controller Configuration (Banks)
BANKS_CONTROLLER_CONFIG = {
    'host': "10.37.23.200",
    'port': 22,
    'user': "econolite",
    'password': "ecpi2ecpi",
    'remote_folder': "/opt/econolite/set1"
}

# EVO Radar Device Configuration (Banks)
BANKS_EVO_CONFIG = {
    'host': "10.37.23.201", #evo
    'port': 22,
    'user': "evo",
    'password': "root",
    'remote_folder': "/home/evo/Documents/SPM_Data_All"
    #'remote_folder': "/home/evo/Desktop/"
}

# %%
# --- EXAMPLE USAGE ---

# Choose the device you want to download from
#CURRENT_CONFIG = BANKS_CONTROLLER_CONFIG
CURRENT_CONFIG = BANKS_EVO_CONFIG

# Choose the mode and time interval
DOWNLOAD_MODE = 'once'  # Options: 'once', 'continuous'
DOWNLOAD_INTERVAL_HOURS = 0.25 # Run every 15 minutes for continuous mode

# Execute the function
if __name__ == "__main__":
    download_remote_files(
        device_config=CURRENT_CONFIG, 
        mode=DOWNLOAD_MODE, 
        t_hour=DOWNLOAD_INTERVAL_HOURS
    )
# Out:
# [2025-12-15 08:07:47.812665] Starting SCP download job from 10.37.23.201...
# [2025-12-15 08:07:47.812665] Attempting to connect to evo@10.37.23.201:22
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0000.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0015.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0030.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0045.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0100.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0115.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0130.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0145.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0200.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0215.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0230.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0245.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0300.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0315.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0330.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0345.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0400.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0415.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0430.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0445.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0500.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0515.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0530.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0545.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0600.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0615.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0630.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0645.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0700.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0715.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0730.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0745.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0800.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0815.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0830.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0845.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0900.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0915.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0930.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_0945.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1000.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1015.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1030.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1045.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1100.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1115.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1130.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1145.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1200.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1215.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1230.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1245.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1300.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1315.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1330.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1345.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1400.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1415.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1430.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1445.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1500.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1515.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1530.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1545.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1600.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1615.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1630.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1645.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1700.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1715.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1730.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1745.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1800.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1815.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1830.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1845.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1900.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1915.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1930.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_1945.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2000.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2015.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2030.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2045.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2100.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2115.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2130.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2145.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2200.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2215.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2230.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2245.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2300.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2315.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2330.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_09_2345.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0000.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0015.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0030.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0045.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0100.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0115.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0130.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0145.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0200.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0215.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0230.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0245.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0300.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0315.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0330.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0345.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0400.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0415.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0430.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0445.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0500.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0515.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0530.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0545.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0600.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0615.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0630.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0645.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0700.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0715.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0730.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0745.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0800.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0815.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0830.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0845.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0900.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0915.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0930.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_0945.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1000.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1015.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1030.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1045.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1100.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1115.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1130.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1145.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1200.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1215.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1230.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1245.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1300.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1315.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1330.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1345.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1400.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1415.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1430.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1445.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1500.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1515.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1530.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1545.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1600.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1615.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1630.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1645.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1700.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1715.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1730.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1745.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1800.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1815.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1830.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1845.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1900.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1915.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1930.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_1945.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2000.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2015.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2030.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2045.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2100.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2115.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2130.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2145.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2200.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2215.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2230.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2245.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2300.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2315.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2330.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_10_2345.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0000.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0015.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0030.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0045.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0100.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0115.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0130.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0145.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0200.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0215.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0230.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0245.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0300.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0315.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0330.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0345.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0400.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0415.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0430.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0445.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0500.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0515.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0530.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0545.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0600.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0615.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0630.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0645.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0700.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0715.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0730.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0745.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0800.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0815.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0830.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0845.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0900.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0915.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0930.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_0945.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1000.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1015.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1030.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1045.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1100.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1115.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1130.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1145.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1200.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1215.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1230.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1245.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1300.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1315.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1330.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1345.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1400.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1415.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1430.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1445.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1500.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1515.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1530.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1545.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1600.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1615.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1630.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1645.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1700.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1715.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1730.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1745.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1800.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1815.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1830.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1845.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1900.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1915.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1930.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_1945.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2000.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2015.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2030.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2045.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2100.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2115.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2130.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2145.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2200.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2215.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2230.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2245.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2300.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2315.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2330.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_11_2345.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_12_0000.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_12_0015.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_12_0030.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_12_0045.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_12_0100.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_12_0115.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_12_0130.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_12_0145.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_12_0200.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_12_0215.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_12_0230.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_12_0245.datZ
# Skipping (already exists locally): ECON_10.37.23.200_2025_12_12_0300.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0315.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0330.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0345.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0400.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0415.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0430.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0445.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0500.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0515.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0530.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0545.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0600.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0615.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0630.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0645.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0700.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0715.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0730.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0745.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0800.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0815.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0830.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0845.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0900.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0915.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0930.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_0945.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1000.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1015.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1030.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1045.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1100.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1115.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1130.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1145.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1200.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1215.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1230.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1245.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1300.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1315.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1330.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1345.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1400.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1415.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1430.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1445.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1500.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1515.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1530.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1545.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1600.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1615.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1630.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1645.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1700.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1715.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1730.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1745.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1800.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1815.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1830.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1845.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1900.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1915.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1930.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_1945.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2000.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2015.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2030.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2045.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2100.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2115.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2130.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2145.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2200.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2215.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2230.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2245.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2300.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2315.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2330.datZ
# Downloading: ECON_10.37.23.200_2025_12_12_2345.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0000.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0015.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0030.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0045.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0100.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0115.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0130.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0145.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0200.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0215.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0230.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0245.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0300.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0315.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0330.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0345.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0400.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0415.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0430.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0445.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0500.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0515.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0530.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0545.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0600.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0615.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0630.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0645.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0700.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0715.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0730.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0745.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0800.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0815.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0830.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0845.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0900.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0915.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0930.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_0945.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1000.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1015.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1030.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1045.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1100.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1115.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1130.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1145.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1200.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1215.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1230.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1245.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1300.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1315.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1330.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1345.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1400.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1415.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1430.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1445.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1500.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1515.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1530.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1545.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1600.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1615.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1630.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1645.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1700.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1715.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1730.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1745.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1800.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1815.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1830.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1845.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1900.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1915.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1930.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_1945.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2000.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2015.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2030.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2045.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2100.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2115.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2130.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2145.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2200.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2215.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2230.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2245.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2300.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2315.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2330.datZ
# Downloading: ECON_10.37.23.200_2025_12_13_2345.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0000.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0015.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0030.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0045.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0100.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0115.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0130.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0145.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0200.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0215.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0230.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0245.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0300.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0315.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0330.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0345.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0400.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0415.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0430.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0445.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0500.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0515.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0530.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0545.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0600.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0615.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0630.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0645.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0700.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0715.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0730.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0745.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0800.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0815.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0830.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0845.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0900.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0915.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0930.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_0945.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1000.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1015.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1030.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1045.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1100.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1115.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1130.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1145.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1200.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1215.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1230.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1245.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1300.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1315.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1330.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1345.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1400.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1415.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1430.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1445.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1500.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1515.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1530.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1545.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1600.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1615.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1630.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1645.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1700.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1715.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1730.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1745.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1800.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1815.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1830.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1845.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1900.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1915.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1930.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_1945.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2000.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2015.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2030.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2045.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2100.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2115.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2130.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2145.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2200.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2215.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2230.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2245.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2300.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2315.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2330.datZ
# Downloading: ECON_10.37.23.200_2025_12_14_2345.datZ
# Downloading: ECON_10.37.23.200_2025_12_15_0000.datZ
# Downloading: ECON_10.37.23.200_2025_12_15_0015.datZ
# Downloading: ECON_10.37.23.200_2025_12_15_0030.datZ
# Downloading: ECON_10.37.23.200_2025_12_15_0045.datZ
# Downloading: ECON_10.37.23.200_2025_12_15_0100.datZ
# Downloading: ECON_10.37.23.200_2025_12_15_0115.datZ
# Downloading: ECON_10.37.23.200_2025_12_15_0130.datZ
# Downloading: ECON_10.37.23.200_2025_12_15_0145.datZ
# Downloading: ECON_10.37.23.200_2025_12_15_0200.datZ
# Downloading: ECON_10.37.23.200_2025_12_15_0215.datZ
# Downloading: ECON_10.37.23.200_2025_12_15_0230.datZ
# Downloading: ECON_10.37.23.200_2025_12_15_0245.datZ
# Downloading: ECON_10.37.23.200_2025_12_15_0300.datZ
# [2025-12-15 08:11:31.862823] Download job completed successfully.
